# %%
#importing the required libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split

# %%
#loading the given file monet.csv into dataset

dataset = pd.read_csv('monet.csv')

dataset
# Out:
#         PRICE  HEIGHT  WIDTH  SIGNED  PICTURE  HOUSE
# 0    3.993780    21.3   25.6       1        1       1
# 1    8.800000    31.9   25.6       1        2       2
# 2    0.131694     6.9   15.9       0        3       3
# 3    2.037500    25.7   32.0       1        4       2
# 4    1.487500    25.7   32.0       1        4       2
# ..        ...     ...    ...     ...      ...     ...
# 425  5.282500    25.6   39.4       1      375       1
# 426  9.352500    25.9   39.6       1      375       2
# 427  8.252500    25.6   39.6       1      375       1
# 428  3.410000    25.6   39.4       1      386       2
# 429  1.542500    25.7   32.0       1      387       1
#
# [430 rows x 6 columns]

# %%
#Task -1:
#model-1 
# Creatig new independent variable as size = height * width
#it is important to determine cost

height = dataset['HEIGHT']
width = dataset['WIDTH']

# %%
dataset['SIZE'] = height * width
dataset['SIZE']

# considering size = height * width
# Out:
# 0       545.28
# 1       816.64
# 2       109.71
# 3       822.40
# 4       822.40
#         ...
# 425    1008.64
# 426    1025.64
# 427    1013.76
# 428    1008.64
# 429     822.40
# Name: SIZE, Length: 430, dtype: float64

# %%
# determining the independent variable SIZE as x and dependent variable PRICE as y
# Considering one variable as PRICE and the other as SIZE = height * width

x = dataset['SIZE'].values
y = dataset['PRICE'].values

#splitting the dataset
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.5,random_state=40)

# %%
x_train = x_train.reshape(-1,1)
y_train = y_train.reshape(-1,1)
x_test = x_test.reshape(-1,1)
y_test = y_test.reshape(-1,1)

# %%
regr=LinearRegression()

# %%
regr1=regr.fit(x_train,y_train)
#this is fitting the simple regression to linear regression

# %%
y_predic=regr.predict(x_test)
y_predic

#The above is for predicting the test results
# Out:
# array([[ 3.54541475],
#        [ 2.02813901],
#        [ 2.76477809],
#        [ 1.8055425 ],
#        [ 4.96444711],
#        [ 1.22390809],
#        [ 2.58049604],
#        [ 2.48453521],
#        [ 2.49646044],
#        [ 4.28384728],
#        [ 3.6519499 ],
#        [ 2.1372828 ],
#        [ 2.75285286],
#        [ 2.33300096],
#        [ 2.78956021],
#        [ 2.36984805],
#        [ 4.0265232 ],
#        [ 2.19641982],
#        [ 3.52179721],
#        [ 2.18689361],
#        [ 3.307376  ],
#        [ 2.50987633],
#        [ 2.35885448],
#        [ 2.50987633],
#        [ 2.7601198 ],
#        [ 2.42043711],
#        [ 2.08198887],
#        [ 1.36135102],
#        [ 2.17196379],
#        [ 2.49646044],
#        [ 2.34786091],
#        [ 2.36984805],
#        [ 7.81655658],
#        [ 1.81695531],
#        [ 1.7976234 ],
#        [ 1.87434548],
#        [ 2.75285286],
#        [ 2.80474624],
#        [ 2.51288092],
#        [ 1.2803666 ],
#        [ 3.41477294],
# ...

# %%
#mean square error
np.sqrt(mean_squared_error(y_test,y_predic))
# Out:
# 4.296105632943739

# %%
#Scatter plot with regression line

plt.scatter(x,y,color='blue')  
#this is actual data
plt.plot(x_train,regr.predict(x_train),color='red')
plt.title('Size vs Price ')
plt.xlabel('SIZE')
plt.ylabel('PRICE')

#the above is for visualizing the size
# Out:
# Text(0, 0.5, 'PRICE')

# %%
#model-2 Linear regression with independent variable as width and dependent variable as price
# considering one variable as price and other as width 
# considering price vs width

x = dataset['WIDTH'].values
y = dataset['PRICE'].values

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.5,random_state=40)
#splitting the dataset

# %%
x_train = x_train.reshape(-1,1)
y_train = y_train.reshape(-1,1)
x_test = x_test.reshape(-1,1)

# %%
regr=LinearRegression()
#fitting the data
regr1=regr.fit(x_train,y_train)

#predicting the test data
y_predic = regr.predict(x_test)
y_predic
# Out:
# array([[ 3.54541475],
#        [ 2.02813901],
#        [ 2.76477809],
#        [ 1.8055425 ],
#        [ 4.96444711],
#        [ 1.22390809],
#        [ 2.58049604],
#        [ 2.48453521],
#        [ 2.49646044],
#        [ 4.28384728],
#        [ 3.6519499 ],
#        [ 2.1372828 ],
#        [ 2.75285286],
#        [ 2.33300096],
#        [ 2.78956021],
#        [ 2.36984805],
#        [ 4.0265232 ],
#        [ 2.19641982],
#        [ 3.52179721],
#        [ 2.18689361],
#        [ 3.307376  ],
#        [ 2.50987633],
#        [ 2.35885448],
#        [ 2.50987633],
#        [ 2.7601198 ],
#        [ 2.42043711],
#        [ 2.08198887],
#        [ 1.36135102],
#        [ 2.17196379],
#        [ 2.49646044],
#        [ 2.34786091],
#        [ 2.36984805],
#        [ 7.81655658],
#        [ 1.81695531],
#        [ 1.7976234 ],
#        [ 1.87434548],
#        [ 2.75285286],
#        [ 2.80474624],
#        [ 2.51288092],
#        [ 1.2803666 ],
#        [ 3.41477294],
# ...

# %%
#mean square error 
np.sqrt(mean_squared_error(y_test,y_predic))
# Out:
# 4.2922992090277035

# %%
#scatter plot with regression line
plt.scatter(x,y,color='blue')
#this is actual data
plt.plot(x_train,regr.predict(x_train),color='red')
plt.title('Width vs Price')
plt.xlabel('Width')
plt.ylabel('Price')
# Out:
# Text(0, 0.5, 'Price')

# %%
#with dependent variable as price and independent variable as height
#Considering one variable as price and other as height
# considering height vs price

x = dataset['HEIGHT'].values
y = dataset['PRICE'].values

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.5,random_state=40)

#splitting the dataset

# %%
x_train = x_train.reshape(-1,1)
y_train = y_train.reshape(-1,1)
x_test = x_test.reshape(-1,1)
y_test = y_test.reshape(-1,1)

# %%
regr = LinearRegression()
#fitting the data
regr1 = regr.fit(x_train,y_train)

# %%
#predicting the data
y_predic = regr.predict(x_test)
y_predic
# Out:
# array([[ 3.92446553],
#        [ 1.98971442],
#        [ 2.54806541],
#        [ 1.82091063],
#        [ 5.39176   ],
#        [ 0.73017846],
#        [ 2.65194466],
#        [ 2.54806541],
#        [ 3.36611454],
#        [ 4.39192217],
#        [ 5.18400149],
#        [ 1.98971442],
#        [ 2.54806541],
#        [ 3.36611454],
#        [ 2.31433709],
#        [ 2.28836727],
#        [ 4.08028441],
#        [ 2.31433709],
#        [ 3.36611454],
#        [ 1.98971442],
#        [ 3.37909944],
#        [ 2.56105032],
#        [ 2.28836727],
#        [ 2.56105032],
#        [ 2.28836727],
#        [ 2.40523143],
#        [ 2.09359367],
#        [ 2.09359367],
#        [ 2.28836727],
#        [ 2.54806541],
#        [ 2.28836727],
#        [ 3.41805416],
#        [ 4.33998255],
#        [ 1.5741974 ],
#        [ 1.88583516],
#        [ 1.98971442],
#        [ 2.54806541],
#        [ 2.60000504],
#        [ 2.95059752],
#        [ 1.80792572],
#        [ 2.97656733],
# ...

# %%
#mean square error
np.sqrt(mean_squared_error(y_test,y_predic))
# Out:
# 4.318717630739892

# %%
# scatter plot with regresssion line
plt.scatter(x,y,color='blue')
plt.plot(x_train,regr.predict(x_train),color='red')
plt.title('Height vs Price')
plt.xlabel('Height')
plt.ylabel('Price')
# Out:
# Text(0, 0.5, 'Price')

# %%
#Task2 

# Multi variant linear regression model


dataset
# Out:
#         PRICE  HEIGHT  WIDTH  SIGNED  PICTURE  HOUSE      SIZE
# 0    3.993780    21.3   25.6       1        1       1   545.28
# 1    8.800000    31.9   25.6       1        2       2   816.64
# 2    0.131694     6.9   15.9       0        3       3   109.71
# 3    2.037500    25.7   32.0       1        4       2   822.40
# 4    1.487500    25.7   32.0       1        4       2   822.40
# ..        ...     ...    ...     ...      ...     ...      ...
# 425  5.282500    25.6   39.4       1      375       1  1008.64
# 426  9.352500    25.9   39.6       1      375       2  1025.64
# 427  8.252500    25.6   39.6       1      375       1  1013.76
# 428  3.410000    25.6   39.4       1      386       2  1008.64
# 429  1.542500    25.7   32.0       1      387       1   822.40
#
# [430 rows x 7 columns]

# %%
from sklearn import preprocessing
scaler = preprocessing.MinMaxScaler()

# %%
name = dataset.columns
name
# Out:
# Index(['PRICE', 'HEIGHT', 'WIDTH', 'SIGNED', 'PICTURE', 'HOUSE '], dtype='object')

# %%
df = scaler.fit_transform(dataset)

# %%
scaled_df = pd.DataFrame(df, columns=name)

# %%
scaled_df.columns
# Out:
# Index(['PRICE', 'HEIGHT', 'WIDTH', 'SIGNED', 'PICTURE', 'HOUSE '], dtype='object')

# %%
x = scaled_df.iloc[:,1:]
y = scaled_df.iloc[:,:1]

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.5, random_state = 40)
#the above is for splitiing data set

# %%
regr=LinearRegression()

# %%
# fitting the ddata
regr1=regr.fit(x_train,y_train)

# %%
#predicting the test data
y_predic=regr.predict(x_test)
y_predic
# Out:
# array([[ 1.51107325e-01],
#        [ 9.21538478e-02],
#        [ 1.04998131e-01],
#        [ 3.89652092e-02],
#        [ 8.86113242e-02],
#        [-6.87055968e-02],
#        [ 1.08414319e-01],
#        [ 3.48425463e-04],
#        [ 1.07425353e-01],
#        [ 1.40568405e-01],
#        [ 5.32545618e-02],
#        [ 9.00294491e-02],
#        [ 1.21222123e-01],
#        [ 5.37834845e-02],
#        [ 9.85018213e-02],
#        [ 8.87926661e-02],
#        [ 1.02726889e-01],
#        [ 8.05384626e-02],
#        [ 1.33883086e-01],
#        [-8.07453647e-03],
#        [ 1.36800976e-01],
#        [ 8.89723829e-02],
#        [ 8.43420992e-02],
#        [ 8.89723829e-02],
#        [ 1.11667216e-01],
#        [ 7.03552290e-02],
#        [ 7.91339510e-02],
#        [ 1.47490418e-02],
#        [ 4.82889101e-02],
#        [ 9.40501011e-02],
#        [ 9.35637155e-02],
#        [ 7.89605548e-02],
#        [ 2.39872789e-01],
#        [ 7.56653257e-02],
#        [ 5.12350878e-02],
# ...

# %%
#root mean square error
np.sqrt(mean_squared_error(y_test,y_predic))
# Out:
# 0.1253086075977087
